# %%
print_menu()
# Out:
# Coffee Menu
# 0. Finish
# 1. Latte = 40
# 2. Espresso = 45
# 3. Americano = 50
# 4. Mocca = 55
# 5. Cappuccino = 60

# %%
order_coffee()
# Out:
# Total price: 450
# ({'Espresso': 10}, 450)

# %%
1001-(1001//1000)*1000
# Out:
# 1

# %%
d = {'h':1,'d':2}

sum(d.values())
# Out:
# 3

# %%
with open('midTermScore_grp01.csv') as file:
    rawDatas = file.read().strip().split('\n')

datas = [dict(zip(rawDatas[0].split(','),rawData.split(','))) for rawData in rawDatas[1:]]
cleanDatas = [data for data in datas if data['Test name'] == '01204111 Midterm Examination 2564-1']

student = len(cleanDatas)
maxScore = int(max(cleanDatas,key=lambda r:int(r['Score']))['Score'])
avgScore = sum([int(data['Score']) for data in cleanDatas])/student
minScore = int(min(cleanDatas,key=lambda r:int(r['Score']))['Score'])

stdScore = (sum([(int(data['Score'])-avgScore)**2 for data in cleanDatas])/student)**0.5

print(student)
print(f'{maxScore} {avgScore:.2f} {stdScore:.2f} {minScore}')

A,Bp,B,Cp,C,Dp,D,F = 0,0,0,0,0,0,0,0

for data in cleanDatas:
    percentage = float(data['Percentage'])
    if percentage > 85:
        A+=1
    elif percentage > 79:
        Bp+=1
    elif percentage > 73:
        B+=1
    elif percentage > 67:
        Cp+=1
    elif percentage > 60:
        C+=1
    elif percentage > 50:
        Dp+=1
    elif percentage > 40:
        D+=1
    else:
        F+=1

print(f'''A: {A}
B+: {Bp}
B: {B}
C+: {Cp}
C: {C}
D+: {Dp}
D: {D}
F: {F}''')
# Out:
# 67
# 40 33.24 5.39 11
# A: 32
# B+: 17
# B: 3
# C+: 9
# C: 2
# D+: 2
# D: 1
# F: 1

# %%
cleanDatas
# Out:
# [{'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:01:24 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '34',
#   'Answered wrong': '8',
#   'Score': '32',
#   'Percentage': '80',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:01:12 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '31',
#   'Answered wrong': '11',
#   'Score': '29',
#   'Percentage': '72.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:59 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '36',
#   'Answered wrong': '6',
#   'Score': '34',
#   'Percentage': '85',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:57 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '40',
#   'Answered wrong': '2',
#   'Score': '38',
#   'Percentage': '95',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:54 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '39',
#   'Answered wrong': '3',
#   'Score': '37',
#   'Percentage': '92.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:53 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '13',
#   'Answered wrong': '29',
#   'Score': '11',
#   'Percentage': '27.5',
#   'Grade': 'F'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:49 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '35',
#   'Answered wrong': '7',
#   'Score': '33',
#   'Percentage': '82.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:48 AM',
#   'Total questions': '42',
#   'Items attempted': '40',
#   'Items not attempted': '2',
#   'Answered correct': '40',
#   'Answered wrong': '0',
#   'Score': '40',
#   'Percentage': '100',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:45 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '37',
#   'Answered wrong': '5',
#   'Score': '35',
#   'Percentage': '87.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:45 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '30',
#   'Answered wrong': '12',
#   'Score': '28',
#   'Percentage': '70',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:40 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '36',
#   'Answered wrong': '6',
#   'Score': '34',
#   'Percentage': '85',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:38 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '39',
#   'Answered wrong': '3',
#   'Score': '37',
#   'Percentage': '92.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:37 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '35',
#   'Answered wrong': '7',
#   'Score': '33',
#   'Percentage': '82.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:36 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '40',
#   'Answered wrong': '2',
#   'Score': '38',
#   'Percentage': '95',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:36 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '41',
#   'Answered wrong': '1',
#   'Score': '39',
#   'Percentage': '97.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:35 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '40',
#   'Answered wrong': '2',
#   'Score': '38',
#   'Percentage': '95',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:34 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '35',
#   'Answered wrong': '7',
#   'Score': '33',
#   'Percentage': '82.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:33 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '40',
#   'Answered wrong': '2',
#   'Score': '38',
#   'Percentage': '95',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:33 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '38',
#   'Answered wrong': '4',
#   'Score': '36',
#   'Percentage': '90',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:33 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '39',
#   'Answered wrong': '3',
#   'Score': '37',
#   'Percentage': '92.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:32 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '35',
#   'Answered wrong': '7',
#   'Score': '33',
#   'Percentage': '82.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:30 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '38',
#   'Answered wrong': '4',
#   'Score': '36',
#   'Percentage': '90',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:28 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '35',
#   'Answered wrong': '7',
#   'Score': '33',
#   'Percentage': '82.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:27 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '39',
#   'Answered wrong': '3',
#   'Score': '37',
#   'Percentage': '92.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:25 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '40',
#   'Answered wrong': '2',
#   'Score': '38',
#   'Percentage': '95',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:25 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '34',
#   'Answered wrong': '8',
#   'Score': '32',
#   'Percentage': '80',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:25 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '30',
#   'Answered wrong': '12',
#   'Score': '28',
#   'Percentage': '70',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:24 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '40',
#   'Answered wrong': '2',
#   'Score': '38',
#   'Percentage': '95',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:24 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '36',
#   'Answered wrong': '6',
#   'Score': '34',
#   'Percentage': '85',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:23 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '41',
#   'Answered wrong': '1',
#   'Score': '39',
#   'Percentage': '97.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:23 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '27',
#   'Answered wrong': '15',
#   'Score': '25',
#   'Percentage': '62.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:22 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '37',
#   'Answered wrong': '5',
#   'Score': '35',
#   'Percentage': '87.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:21 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '22',
#   'Answered wrong': '20',
#   'Score': '20',
#   'Percentage': '50',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:20 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '39',
#   'Answered wrong': '3',
#   'Score': '37',
#   'Percentage': '92.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:19 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '24',
#   'Answered wrong': '18',
#   'Score': '22',
#   'Percentage': '55',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:19 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '30',
#   'Answered wrong': '12',
#   'Score': '28',
#   'Percentage': '70',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:18 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '30',
#   'Answered wrong': '12',
#   'Score': '28',
#   'Percentage': '70',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:18 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '41',
#   'Answered wrong': '1',
#   'Score': '39',
#   'Percentage': '97.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:18 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '37',
#   'Answered wrong': '5',
#   'Score': '35',
#   'Percentage': '87.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:17 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '41',
#   'Answered wrong': '1',
#   'Score': '39',
#   'Percentage': '97.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:16 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '34',
#   'Answered wrong': '8',
#   'Score': '32',
#   'Percentage': '80',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:15 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '37',
#   'Answered wrong': '5',
#   'Score': '35',
#   'Percentage': '87.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:15 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '37',
#   'Answered wrong': '5',
#   'Score': '35',
#   'Percentage': '87.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:15 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '41',
#   'Answered wrong': '1',
#   'Score': '39',
#   'Percentage': '97.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:15 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '36',
#   'Answered wrong': '6',
#   'Score': '34',
#   'Percentage': '85',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:14 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '41',
#   'Answered wrong': '1',
#   'Score': '39',
#   'Percentage': '97.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:13 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '29',
#   'Answered wrong': '13',
#   'Score': '27',
#   'Percentage': '67.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:13 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '32',
#   'Answered wrong': '10',
#   'Score': '30',
#   'Percentage': '75',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:13 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '33',
#   'Answered wrong': '9',
#   'Score': '31',
#   'Percentage': '77.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:12 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '35',
#   'Answered wrong': '7',
#   'Score': '33',
#   'Percentage': '82.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:12 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '29',
#   'Answered wrong': '13',
#   'Score': '27',
#   'Percentage': '67.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:12 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '31',
#   'Answered wrong': '11',
#   'Score': '29',
#   'Percentage': '72.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:12 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '41',
#   'Answered wrong': '1',
#   'Score': '39',
#   'Percentage': '97.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:11 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '37',
#   'Answered wrong': '5',
#   'Score': '35',
#   'Percentage': '87.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:10 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '36',
#   'Answered wrong': '6',
#   'Score': '34',
#   'Percentage': '85',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:10 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '36',
#   'Answered wrong': '6',
#   'Score': '34',
#   'Percentage': '85',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:10 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '24',
#   'Answered wrong': '18',
#   'Score': '22',
#   'Percentage': '55',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:10 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '34',
#   'Answered wrong': '8',
#   'Score': '32',
#   'Percentage': '80',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:09 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '39',
#   'Answered wrong': '3',
#   'Score': '37',
#   'Percentage': '92.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:09 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '39',
#   'Answered wrong': '3',
#   'Score': '37',
#   'Percentage': '92.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:09 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '30',
#   'Answered wrong': '12',
#   'Score': '28',
#   'Percentage': '70',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:09 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '34',
#   'Answered wrong': '8',
#   'Score': '32',
#   'Percentage': '80',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:08 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '28',
#   'Answered wrong': '14',
#   'Score': '26',
#   'Percentage': '65',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:08 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '39',
#   'Answered wrong': '3',
#   'Score': '37',
#   'Percentage': '92.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:07 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '32',
#   'Answered wrong': '10',
#   'Score': '30',
#   'Percentage': '75',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:06 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '41',
#   'Answered wrong': '1',
#   'Score': '39',
#   'Percentage': '97.5',
#   'Grade': 'P'},
#  {'Test name': '01204111 Midterm Examination 2564-1',
#   'Test taken on': '22-08-2021 09:00:05 AM',
#   'Total questions': '42',
#   'Items attempted': '42',
#   'Items not attempted': '0',
#   'Answered correct': '40',
#   'Answered wrong': '2',
#   'Score': '38',
#   'Percentage': '95',
#   'Grade': 'P'}]
